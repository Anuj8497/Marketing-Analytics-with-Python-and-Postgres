# %%
import pandas as pd

import psycopg2 as pg2
con = pg2.connect(host='localhost', user='postgres',database='dummy',password = '1234')
con.autocommit = True
cur = con.cursor()

# %%
def select(sql):
    return pd.read_sql(sql,con)

# %%
sql = '''
SELECT pid , query, *
FROM pg_stat_activity pgsa
WHERE pid <> pg_backend_pid()
'''

# %%
df = select(sql)
df
# Out:
#       pid                                              query    datid datname  \
# 0   34372                                                         NaN    None
# 1   33600  /*pga4dash*/\nSELECT 'session_stats' AS chart_...  16398.0   dummy
# 2   38212                                                         NaN    None
# 3   22540                                           ROLLBACK  16398.0   dummy
# 4   14908  /*pga4dash*/\nSELECT 'session_stats' AS chart_...  16394.0    Test
# 5   37928                                           ROLLBACK  16398.0   dummy
# 6   15404                                             COMMIT  16398.0   dummy
# 7   28140                    drop table churn_report_prelim;  16398.0   dummy
# 8   32748                                                         NaN    None
# 9   40356                                                         NaN    None
# 10  39928                                                         NaN    None
#
#       pid leader_pid  usesysid   usename          application_name  \
# 0   34372       None       NaN      None
# 1   33600       None      10.0  postgres      pgAdmin 4 - DB:dummy
# 2   38212       None      10.0  postgres
# 3   22540       None      10.0  postgres
# 4   14908       None      10.0  postgres       pgAdmin 4 - DB:Test
# 5   37928       None      10.0  postgres
# 6   15404       None      10.0  postgres
# 7   28140       None      10.0  postgres  pgAdmin 4 - CONN:6629997
# 8   32748       None       NaN      None
# 9   40356       None       NaN      None
# 10  39928       None       NaN      None
#
#    client_addr  ... xact_start                      query_start  \
# 0         None  ...       None                              NaT
# 1          ::1  ...       None 2021-02-12 07:28:00.032420+00:00
# 2         None  ...       None                              NaT
# 3          ::1  ...       None 2021-02-12 07:13:58.689919+00:00
# 4          ::1  ...       None 2021-02-12 07:15:46.933514+00:00
# 5          ::1  ...       None 2021-02-12 07:25:14.220926+00:00
# 6          ::1  ...       None 2021-02-12 07:15:42.684159+00:00
# 7          ::1  ...       None 2021-02-12 07:27:54.963779+00:00
# 8         None  ...       None                              NaT
# 9         None  ...       None                              NaT
# 10        None  ...       None                              NaT
#
#                        state_change wait_event_type           wait_event  \
# 0                               NaT        Activity       AutoVacuumMain
# 1  2021-02-12 07:28:00.075951+00:00          Client           ClientRead
# 2                               NaT        Activity  LogicalLauncherMain
# 3  2021-02-12 07:13:58.689932+00:00          Client           ClientRead
# 4  2021-02-12 07:15:46.951273+00:00          Client           ClientRead
# 5  2021-02-12 07:25:14.221065+00:00          Client           ClientRead
# 6  2021-02-12 07:15:42.684585+00:00          Client           ClientRead
# 7  2021-02-12 07:27:54.973631+00:00          Client           ClientRead
# 8                               NaT        Activity    BgWriterHibernate
# 9                               NaT        Activity     CheckpointerMain
# 10                              NaT        Activity        WalWriterMain
#
#    state backend_xid backend_xmin  \
# 0   None        None         None
# 1   idle        None         None
# 2   None        None         None
# 3   idle        None         None
# 4   idle        None         None
# 5   idle        None         None
# 6   idle        None         None
# 7   idle        None         None
# 8   None        None         None
# 9   None        None         None
# 10  None        None         None
#
#                                                 query  \
# 0
# 1   /*pga4dash*/\nSELECT 'session_stats' AS chart_...
# 2
# 3                                            ROLLBACK
# 4   /*pga4dash*/\nSELECT 'session_stats' AS chart_...
# 5                                            ROLLBACK
# 6                                              COMMIT
# 7                     drop table churn_report_prelim;
# 8
# 9
# 10
#
#                     backend_type
# 0            autovacuum launcher
# 1                 client backend
# 2   logical replication launcher
# 3                 client backend
# 4                 client backend
# 5                 client backend
# 6                 client backend
# 7                 client backend
# 8              background writer
# 9                   checkpointer
# 10                     walwriter
#
# [11 rows x 23 columns]

# %%
sql = '''
SELECT 
    pg_terminate_backend(pid) 
FROM 
    pg_stat_activity 
WHERE 
    -- don't kill my own connection!
    pid <> pg_backend_pid()

'''

# %%
cur.execute(sql)
